# %%
class Borg:
    _shared_state = {}

    def __init__(self):
        self.__dict__ = self._shared_state

class PrototypeFactory(Borg):
    def __init__(self):
        """ Initia;izer """
        self._registry = {}
        
def register(self, instance):
    """ Register an instance """
    self._registry[instance.__class__] = instance
    
def clone(self, klass):
    """ Clone a registered instance """
    instance = self._registry.get(klass)
    if not instance:
        raise ValueError(f"Class {klass} not registered.")
    return instance.clone()

# %%
import timeit
import dis

time1 = timeit.timeit("[]", number=1000000)
time2 = timeit.timeit("list()", number=1000000)

print(f"[]: {time1}")
print(f"list(): {time2}")

dis.dis("[]")

dis.dis("list()")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import timeit
#       2 import dis
# ----> 4 time1 = timeit.timeit("[], number=1000000")
#       5 time2 = timeit.timeit("list()", number=1000000)
#       7 print(f"[]: {time1}")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\timeit.py:237, in timeit(stmt, setup, timer, number, globals)
#     234 def timeit(stmt="pass", setup="pass", timer=default_timer,
#     235            number=default_number, globals=None):
#     236     """Convenience function to create Timer object and call timeit method."""
# --> 237     return Timer(stmt, setup, timer, globals).timeit(number)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\timeit.py:180, in Timer.timeit(self, number)
#     178 gc.disable()
#     179 try:
# --> 180     timing = self.inner(it, self.timer)
#     181 finally:
# ...
